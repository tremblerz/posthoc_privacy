# %%
import sdv
from sdv.tabular import TVAE
from sdv.demo import load_tabular_demo

# %%
data = load_tabular_demo('SAP_v1')
data.head()
# Out:
#    ID     SEX      MARITAL_STATUS  GEOID  EDUCATIONNUM         OCCUPATION  \
# 0   0    Male       Never-married     61             7  Machine-op-inspct
# 1   1    Male  Married-civ-spouse     70             3  Handlers-cleaners
# 2   2    Male       Never-married     53             7  Machine-op-inspct
# 3   3  Female            Divorced     79             4    Exec-managerial
# 4   4    Male  Married-civ-spouse     46             4  Handlers-cleaners
#
#    DATA1  DATA2  DATA3 NOM1 NOM2 NOM3  age  add_numerical  sum(KxIndex)  \
# 0  9.276  3.592  8.253    l    p    o   62         80.845           1.0
# 1  5.836  4.574  5.507    u    r    x   78         92.081           2.0
# 2  8.998  4.184  8.593    n    q    o   69         90.777           3.0
# 3  5.201  5.101  5.461    z    r    y   53         70.562           4.0
# 4  5.683  6.391  6.757    x    m    n   85        106.148           5.0
#
#    sum(AMOUNT)  max(AMOUNT)  min(AMOUNT)  nb_rows_in_Mailings1_2  \
# ...

# %%
sdv.demo.get_available_demos()
# Out:
#                      name  tables     rows  columns
# 0                UTube_v1       2     2735       10
# 1                  SAP_v1       4  3841029       71
# 2                 NCAA_v1       9   202305      333
# 3       airbnb-simplified       2  5751408       22
# 4      Atherosclerosis_v1       4    12781      307
# 5                rossmann       3  2035533       21
# 6                 walmart       4   544869       24
# 7   AustralianFootball_v1       4   139179      193
# 8           Pyrimidine_v1       2      296       38
# 9                world_v1       3     5302       39
# 10           Accidents_v1       3  1463093       87
# 11              trains_v1       2       83       15
# 12           legalActs_v1       5  1754397       50
# 13                 DCG_v1       2     8258        9
# 14            imdb_ijs_v1       7  5647694       50
# 15             SalesDB_v1       4  6735507       35
# 16           MuskSmall_v1       2      568      173
# ...

# %%
model = TVAE()
model.fit(data)
# Out:
# /u/abhi24/matlaberp2/posthoc_privacy/.projenv/lib/python3.8/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# /u/abhi24/matlaberp2/posthoc_privacy/.projenv/lib/python3.8/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# /u/abhi24/matlaberp2/posthoc_privacy/.projenv/lib/python3.8/site-packages/sklearn/mixture/_base.py:277: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   warnings.warn(
# ...

# %%
model.sample(20)
# Out:
# /u/abhi24/matlaberp2/posthoc_privacy/.projenv/lib/python3.8/site-packages/sdv/tabular/base.py:250: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sampled = previous_rows.append(sampled, ignore_index=True)
#         ID   SEX      MARITAL_STATUS  GEOID  EDUCATIONNUM         OCCUPATION  \
# 0   133642  Male  Married-civ-spouse     52             6  Machine-op-inspct
# 1   132306  Male  Married-civ-spouse     66             5  Handlers-cleaners
# 2   117307  Male  Married-civ-spouse     57             5  Handlers-cleaners
# 3   137529  Male  Married-civ-spouse     53             6  Handlers-cleaners
# 4   119946  Male  Married-civ-spouse     66             3  Handlers-cleaners
# 5   354455  Male  Married-civ-spouse     35             9  Handlers-cleaners
# 6   123719  Male  Married-civ-spouse     63            11  Machine-op-inspct
# ...
